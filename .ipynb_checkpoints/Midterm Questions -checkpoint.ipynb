# %% [markdown]
# ### Multiple-Choice Concept Questions

# %% [markdown]
# Q1. "Data Science" is best illustrated by the famous Data Science venn diagram, highlighting cross-disciplinary nature of the field. Which of these is *not* one of the three disciplines mentioned in the venn diagram?
#
# - (a) Social Science
# - (b) Substantive Expertise
# - (c) Hacking Skills
# - (d) Math & Statistics Knowledge

# %% [markdown]
# Q2. The standard implementation of Python is written in:
# - (a) Java
# - (b) Lisp
# - (c) C
# - (d) Pearl

# %% [markdown]
# Q3. Which of following statistic is *not* of part of the five-number summary statistics?
# - (a) Mean
# - (b) Median
# - (c) Max
# - (d) First Quartile

# %% [markdown]
# Q4. The process of converting an existing times-series to a higher time frequency--which requires filling or interpolating missing data of the new time-series--is known as:
# * (a) Downsampling
# * (b) Upsampling
# * (c) Resampling
# * (d) Oversampling

# %% [markdown]
# Q5. Which of the following was *not* one of reasons stressed by Dr. Grossberg to learn Linear Regression.
# * (a) It's a common language: almost everyone knows it.
# * (b) Can build non-linear regression on top of linear regression.
# * (c) Often works pretty darn well.
# * (d) Your boss will probabily give you a raise for knowing it.

# %% [markdown]
# Q6. Event A and B are dependent if:
# * (a) The probability of A given B is probability of A.
# * (b) The joint probability of A and B is the product of the probabilities that each event happens.
# * (c) the probability of B occuring affects the probability of A occuring, and vice versa.
# * (d) If the probability of A is greater than the probability of B.

# %% [markdown]
# Q7. Models that predict labels as discrete categories is known as which type of machine learning problem?
# * (a) Regression
# * (b) Classification
# * (c) Clustering
# * (d) Dimensionality Reduction

# %% [markdown]
# Q8. Which of the following is *not* computed from a confusion matrix?
# * (a) Accuracy
# * (b) Bias
# * (c) True Negative Rate
# * (d) Precision

# %% [markdown]
# Answers to Multiple Choice questions:
# - Q1) a
# - Q2) c
# - Q3) a
# - Q4) b
# - Q5) d
# - Q6) c
# - Q7) b
# - Q8) b

# %% [markdown]
# ### True-False Questions

# %% [markdown]
# Q1. A set is a immutable data type

# %% [markdown]
# Q2. There are two primary means of using IPython: the shell and notebook.

# %% [markdown]
# Q3. One notable difference between a Python list and NumPy array is that slicing a list gives returns a copy, whereas slicing an array returns a view:

# %% [markdown]
# Q4. You can access the source code of an object in Python with a single question mark (?)

# %% [markdown]
# Q5. Resampling a time-series dataframe or series does not require setting the datetime as the index.

# %% [markdown]
# Q6. One of the reasons for splitting your data into a training and test set is so that you can evaluate your model's ability to predict new or unseen data.

# %% [markdown]
# Q7. Inferring labels on unlabeled data is known as unsupervised learning.

# %% [markdown]
# Answers to True-False Questions
# - Q1) False; a set is mutable.
# - Q2) True
# - Q3) True
# - Q4) False, double question mark returns the source code
# - Q5) False, resampling does requires a datetimeindex
# - Q6) True
# - Q7) True

# %% [markdown]
# ### Short Answer Datacamp-style Question

# %% [markdown]
# #### 1) Simple Linear Regression and Residuals Plot with Seaborn

# %%
# Import pandas, matplotlib, and seaborn modules
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#read in automobile data set (csv link is stored as auto_csv) from datacamp and print head
auto_csv='https://assets.datacamp.com/production/course_1761/datasets/auto-mpg.csv'
df_auto = pd.read_csv(auto_csv)
df_auto.head()

#plot a linear regression between 'mpg' (y-axis) and 'hp' (x-axis)
sns.lmplot(x='hp', y='mpg', data=df_auto)
plt.show()

#plot the residuals of the regression with seaborn's residplot()
sns.residplot(x='hp', y='mpg', data=df_auto)
plt.show()

# %% [markdown]
# #### 2) Some time-series manipulation and plotting

# %%
#Import pandas, numpy and matplotlib.pyplot. set plot style to seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline 

stocks_csv='https://assets.datacamp.com/production/course_1761/datasets/stocks.csv'

#load csv file to a pandas dataframe, parse 'date' as datetime, and set as index.
#print tail of df
df_stocks = pd.read_csv(stocks_csv, parse_dates=['Date'], index_col='Date')
print(df_stocks.tail())

#plot the prices for all four stocks. use pandas plot method, set subplot to true.
_ = df_stocks.plot()
plt.show()

#calculate a rolling 360 days mean for all the stocks and plot them
_ = df_stocks.rolling('365D').mean().plot()
plt.show()

# Plot the rolling mean and std for APPL; set subplot to true; set title to AAPL.
_ = df_stocks.AAPL.rolling(365).agg(['mean', 'std']).plot(title='AAPL 365-day rolling mean and std',subplots=True)
plt.show()
# Out:
#                   AAPL         IBM       CSCO       MSFT
# Date
# 2013-12-24  567.669975  183.220001  21.690001  37.080002
# 2013-12-26  563.900009  185.350006  21.799999  37.439999
# 2013-12-27  560.089989  185.080002  22.020000  37.290001
# 2013-12-30  554.519981  186.410004  22.250000  37.290001
# 2013-12-31  561.019997  187.570007  22.430000  37.410000

# %% [markdown]
# #### 3) Scraping the Spring 2019 Academic Calendar with requests and BeautifulSoup

# %%
#first import requests 
import requests
url = 'https://www.ccny.cuny.edu/registrar/spring-2019-academic-calendar'
req = requests.get(url)

#check status code; look for 200 
req.status_code

#print out text
req.text

#import beautifulsoup as BS; parse html with beautiful soup
from bs4 import BeautifulSoup as BS
soup = BS(req.text, 'html.parser')

#print the title of the page
print(soup.title)

#store first table as table, since there's only one table
table = soup.find_all('table')[0]

#find all table rows 'tr'
table_rows = table.find_all('tr')

#print first two rows; the text is inside the td
print(table_rows[0:2])
# Out:
# <title>Spring 2019 Academic Calendar | The City College of New York</title>
# [<tr><td style="width:119px;">
# <p><strong>DATES</strong></p>
# </td>
# <td style="width:138px;">
# <p><strong>DAYS</strong></p>
# </td>
# <td style="width:390px;">
# <p> </p>
# </td>
# </tr>, <tr><td style="width:119px;height:40px;">
# <h3>November</h3>
# </td>
# <td style="width:138px;height:40px;"> </td>
# <td style="width:390px;height:40px;"> </td>
# </tr>]

# %%
#Import pandas
import pandas as pd

#iterate through each table row and extract the text and append to a list. 
l=[]
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip().replace('\n', ' ') for tr in td]
    l.append(row)

#turn list into dataframe; start at third row;  assign columns as Date, Day, Description
df = pd.DataFrame(l[2:], columns=['Date', 'Day', 'Description'])
df
# Out:
#                        Date                  Day  \
# 0               November 12               Monday
# 1                   January
# 2                January 18               Friday
# 3                January 24             Thursday
# 4                January 25               Friday
# 5   January 25 - January 31    Friday - Thursday
# 6                January 26             Saturday
# 7                January 28               Monday
# 8                January 31             Thursday
# 9                  February
# 10              February 01               Friday
# 11              February 07             Thursday
# 12              February 12              Tuesday
# 13              February 14             Thursday
# 14              February 15               Friday
# 15              February 18               Monday
# 16              February 22               Friday
# 17              February 25               Monday
# 18              February 28             Thursday
# 19                    March
# 20                 March 12              Tuesday
# 21                 March 15               Friday
# 22                    April
# 23                 April 01               Monday
# 24                 April 02              Tuesday
# 25                 April 12               Friday
# 26      April 19 – April 28      Friday – Sunday
# 27                      May
# 28                   May 14              Tuesday
# 29                   May 15            Wednesday
# 30          May 16 - May 22  Thursday- Wednesday
# 31                   May 22            Wednesday
# 32                   May 27               Monday
# 33                   May 28              Tuesday
# 34                   May 31               Friday
#
#                                           Description
# 0   Application for Degree for May 2019 Graduation...
# 1
# 2                  Last day to apply for Study Abroad
# 3   Last day for 100% tuition refund; Last day of ...
# 4   Start of Spring Term; Classes begin; Appeals f...
# 5           Change of program period; late fees apply
# 6                       First day of Saturday Classes
# 7   Last day to submit a request for Independent S...
# 8   Last day to add a course to an existing enroll...
# 9
# 10  Course Withdrawal drop period begins (A grade ...
# 11                   Last day for 50% tuition refund;
# 12                                     College Closed
# 13  Last day for 25% tuition refund; Census date –...
# 14  Course withdrawal period begins (A grade of “W...
# 15                                  College is closed
# 16  Last day to submit proof of immunization for N...
# 17  "WA" Grades assigned - Immunization non-compli...
# 18  Deadline for filling application for Degree fo...
# 19
# 20  Last day to submit proof of immunization for n...
# 21  FAFSA priority deadline for 2019 - 2020 Financ...
# 22
# 23  Course withdrawal period ends.  Last day to wi...
# 24  Registration appointments for Summer 2019 and ...
# 25  INC grades for Fall 2018 for Undergraduate stu...
# 26                                      Spring Recess
# 27
# 28                                Last Day of Classes
# 29                   Reading Day / Final Examinations
# 30            Final Examination - Day/Evening Classes
# 31                                 End of Spring Term
# 32                                     College Closed
# 33                    Final Grade Submission Deadline
# 34                                       Commencement

# %% [markdown]
# #### 4) Getting Boston dataset from sklearn and predicting prices with a Linear Regression. (this is an example from scipy-lectures.org)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#load boston dataset and iris data set and print their keys
data = datasets.load_boston()
data.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)
clf = LinearRegression()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)
expected = y_test

plt.figure(figsize=(4, 3))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.tight_layout()

# %%
data_bos.data.shape
# Out:
# (506, 13)

# %%
l = [1,2,3,4,4,5]
l[0:-1]
# Out:
# [1, 2, 3, 4, 4]

# %% [markdown]
# #### 5) Another Skilearn problem - Classification problem (knn)

# %% [markdown]
# ## Mini-Data Set Question
#
# -Supervised Learning example using scikit-learn data

# %%
from sklearn import neighbors, datasets
iris = datasets.load_iris()
X, y = iris.data, iris.target
knn = neighbors.KNeighborsClassifier(n_neighbors=1)
knn.fit(X, y)
# What kind of iris has 3cm x 5cm sepal and 4cm x 2cm petal?
print(iris.target_names[knn.predict([[3, 5, 4, 2]])])
# Out:
# ['virginica']
